# %%
import sys
sys.path.append("..")
from csympy import var
var("x y z w")
# Out:
# (x, y, z, w)

# %%
e = (x+y+z+w)**15
f = e*(e+w)

# %%
f
# Out:
# (y + x + z + w)^15*((y + x + z + w)^15 + w)

# %%
# %time g = f.expand()
# Out:
# CPU times: user 2.60 s, sys: 0.00 s, total: 2.60 s
# Wall time: 2.61 s
